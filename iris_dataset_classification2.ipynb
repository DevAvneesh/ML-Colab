# %% [markdown]
# <a href="https://colab.research.google.com/github/DevAvneesh/ML-Colab/blob/practice/iris_dataset_classification2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
